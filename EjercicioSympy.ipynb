# %%
import sympy as sym
sym.init_printing()
# %matplotlib notebook

# %% [markdown]
# **Ejercicio**
#
#
# ![circuito_mallas.PNG](figuras/circuito_mallas.PNG)
#
# A partir de este circuito encuentre las expresiones matemáticas para el voltaje en cada resistencia en función de $Vi$.
#
# \begin{align}
# V1 &= expresión\\
# V2 &= expresión\\
# V3 &= expresión\\
# V4 &= expresión\\
# V5 &= expresión\\
# V6 &= expresión\\
# V7 &= expresión\\
# V8 &= expresión\\
# \end{align}

# %%
V1,V2,V3,V4,V5,V7,V8 = sym.symbols('V_1,V_2,V_3,V_4,V_5,V_7,V_8')
R1,R2,R3,R4,R5,R7,R8 = sym.symbols('R_1,R_2,R_3,R_4,R_5,R_7,R_8')
Vi,I1,I2,I3,I4 = sym.symbols('V_i,I_1,I_2,I_3,I_4')

e1 = -Vi + V1 + V4
e2 = -V4 + V3 + V5 + V7
e3 = -V7 + V8
e4 = -V3 + V2
e5 = V1 + I1*R1
e6 = V2 - I2*R2
e7 = V3 - (-I2+I3)*R3
e8 = V4 - (-I3+I1)*R4
e9 = V5 - I3*R5
e10 = V7 - (-I4+I3)*R7
e11 = V8 - I4*R8

# %%
s = sym.solve([e1,e2,e3,e4,e5,e6,e7,e8,e9,e10,e11],
              [V1,V2,V3,V4,V5,V7,V8,I1,I2,I3,I4])
s
# Out:
# ⎧                                                            -R₂⋅R₃⋅R₇⋅Vᵢ - R₂
# ⎨I₁: ─────────────────────────────────────────────────────────────────────────
# ⎩    R₁⋅R₂⋅R₃⋅R₇ + R₁⋅R₂⋅R₃⋅R₈ + R₁⋅R₂⋅R₄⋅R₇ + R₁⋅R₂⋅R₄⋅R₈ + R₁⋅R₂⋅R₅⋅R₇ + R₁⋅
#
# ⋅R₃⋅R₈⋅Vᵢ - R₂⋅R₄⋅R₇⋅Vᵢ - R₂⋅R₄⋅R₈⋅Vᵢ - R₂⋅R₅⋅R₇⋅Vᵢ - R₂⋅R₅⋅R₈⋅Vᵢ - R₂⋅R₇⋅R₈⋅V
# ──────────────────────────────────────────────────────────────────────────────
# R₂⋅R₅⋅R₈ + R₁⋅R₂⋅R₇⋅R₈ + R₁⋅R₃⋅R₄⋅R₇ + R₁⋅R₃⋅R₄⋅R₈ + R₁⋅R₃⋅R₅⋅R₇ + R₁⋅R₃⋅R₅⋅R₈
#
# ᵢ - R₃⋅R₄⋅R₇⋅Vᵢ - R₃⋅R₄⋅R₈⋅Vᵢ - R₃⋅R₅⋅R₇⋅Vᵢ - R₃⋅R₅⋅R₈⋅Vᵢ - R₃⋅R₇⋅R₈⋅Vᵢ
# ──────────────────────────────────────────────────────────────────────────────
#  + R₁⋅R₃⋅R₇⋅R₈ - R₂⋅R₃⋅R₄⋅R₇ - R₂⋅R₃⋅R₄⋅R₈ - R₂⋅R₄⋅R₅⋅R₇ - R₂⋅R₄⋅R₅⋅R₈ - R₂⋅R₄
#
#
# ────────────────────────────────────────────────, I₂: ────────────────────────
# ⋅R₇⋅R₈ - R₃⋅R₄⋅R₅⋅R₇ - R₃⋅R₄⋅R₅⋅R₈ - R₃⋅R₄⋅R₇⋅R₈      R₁⋅R₂⋅R₃⋅R₇ + R₁⋅R₂⋅R₃⋅R
#
#
# ──────────────────────────────────────────────────────────────────────────────
# ₈ + R₁⋅R₂⋅R₄⋅R₇ + R₁⋅R₂⋅R₄⋅R₈ + R₁⋅R₂⋅R₅⋅R₇ + R₁⋅R₂⋅R₅⋅R₈ + R₁⋅R₂⋅R₇⋅R₈ + R₁⋅R
#
#                         -R₃⋅R₄⋅R₇⋅Vᵢ - R₃⋅R₄⋅R₈⋅Vᵢ
# ──────────────────────────────────────────────────────────────────────────────
# ₃⋅R₄⋅R₇ + R₁⋅R₃⋅R₄⋅R₈ + R₁⋅R₃⋅R₅⋅R₇ + R₁⋅R₃⋅R₅⋅R₈ + R₁⋅R₃⋅R₇⋅R₈ - R₂⋅R₃⋅R₄⋅R₇
#
#
# ──────────────────────────────────────────────────────────────────────────────
# - R₂⋅R₃⋅R₄⋅R₈ - R₂⋅R₄⋅R₅⋅R₇ - R₂⋅R₄⋅R₅⋅R₈ - R₂⋅R₄⋅R₇⋅R₈ - R₃⋅R₄⋅R₅⋅R₇ - R₃⋅R₄⋅
#
#
# ───────────────────, I₃: ─────────────────────────────────────────────────────
# R₅⋅R₈ - R₃⋅R₄⋅R₇⋅R₈      R₁⋅R₂⋅R₃⋅R₇ + R₁⋅R₂⋅R₃⋅R₈ + R₁⋅R₂⋅R₄⋅R₇ + R₁⋅R₂⋅R₄⋅R₈
#
#                                                            -R₂⋅R₄⋅R₇⋅Vᵢ - R₂⋅R
# ──────────────────────────────────────────────────────────────────────────────
#  + R₁⋅R₂⋅R₅⋅R₇ + R₁⋅R₂⋅R₅⋅R₈ + R₁⋅R₂⋅R₇⋅R₈ + R₁⋅R₃⋅R₄⋅R₇ + R₁⋅R₃⋅R₄⋅R₈ + R₁⋅R₃
#
# ₄⋅R₈⋅Vᵢ - R₃⋅R₄⋅R₇⋅Vᵢ - R₃⋅R₄⋅R₈⋅Vᵢ
# ──────────────────────────────────────────────────────────────────────────────
# ⋅R₅⋅R₇ + R₁⋅R₃⋅R₅⋅R₈ + R₁⋅R₃⋅R₇⋅R₈ - R₂⋅R₃⋅R₄⋅R₇ - R₂⋅R₃⋅R₄⋅R₈ - R₂⋅R₄⋅R₅⋅R₇ -
#
#
# ────────────────────────────────────────────────────────────────────, I₄: ────
#  R₂⋅R₄⋅R₅⋅R₈ - R₂⋅R₄⋅R₇⋅R₈ - R₃⋅R₄⋅R₅⋅R₇ - R₃⋅R₄⋅R₅⋅R₈ - R₃⋅R₄⋅R₇⋅R₈      R₁⋅R
#
#
# ──────────────────────────────────────────────────────────────────────────────
# ₂⋅R₃⋅R₇ + R₁⋅R₂⋅R₃⋅R₈ + R₁⋅R₂⋅R₄⋅R₇ + R₁⋅R₂⋅R₄⋅R₈ + R₁⋅R₂⋅R₅⋅R₇ + R₁⋅R₂⋅R₅⋅R₈
#
#                                             -R₂⋅R₄⋅R₇⋅Vᵢ - R₃⋅R₄⋅R₇⋅Vᵢ
# ──────────────────────────────────────────────────────────────────────────────
# + R₁⋅R₂⋅R₇⋅R₈ + R₁⋅R₃⋅R₄⋅R₇ + R₁⋅R₃⋅R₄⋅R₈ + R₁⋅R₃⋅R₅⋅R₇ + R₁⋅R₃⋅R₅⋅R₈ + R₁⋅R₃⋅
#
#
# ──────────────────────────────────────────────────────────────────────────────
# R₇⋅R₈ - R₂⋅R₃⋅R₄⋅R₇ - R₂⋅R₃⋅R₄⋅R₈ - R₂⋅R₄⋅R₅⋅R₇ - R₂⋅R₄⋅R₅⋅R₈ - R₂⋅R₄⋅R₇⋅R₈ -
#
#
# ───────────────────────────────────────, V₁: ─────────────────────────────────
# R₃⋅R₄⋅R₅⋅R₇ - R₃⋅R₄⋅R₅⋅R₈ - R₃⋅R₄⋅R₇⋅R₈      R₁⋅R₂⋅R₃⋅R₇ + R₁⋅R₂⋅R₃⋅R₈ + R₁⋅R₂
#
#      R₁⋅R₂⋅R₃⋅R₇⋅Vᵢ + R₁⋅R₂⋅R₃⋅R₈⋅Vᵢ + R₁⋅R₂⋅R₄⋅R₇⋅Vᵢ + R₁⋅R₂⋅R₄⋅R₈⋅Vᵢ + R₁⋅R₂
# ──────────────────────────────────────────────────────────────────────────────
# ⋅R₄⋅R₇ + R₁⋅R₂⋅R₄⋅R₈ + R₁⋅R₂⋅R₅⋅R₇ + R₁⋅R₂⋅R₅⋅R₈ + R₁⋅R₂⋅R₇⋅R₈ + R₁⋅R₃⋅R₄⋅R₇ +
#
# ⋅R₅⋅R₇⋅Vᵢ + R₁⋅R₂⋅R₅⋅R₈⋅Vᵢ + R₁⋅R₂⋅R₇⋅R₈⋅Vᵢ + R₁⋅R₃⋅R₄⋅R₇⋅Vᵢ + R₁⋅R₃⋅R₄⋅R₈⋅Vᵢ
# ──────────────────────────────────────────────────────────────────────────────
#  R₁⋅R₃⋅R₄⋅R₈ + R₁⋅R₃⋅R₅⋅R₇ + R₁⋅R₃⋅R₅⋅R₈ + R₁⋅R₃⋅R₇⋅R₈ - R₂⋅R₃⋅R₄⋅R₇ - R₂⋅R₃⋅R
#
# + R₁⋅R₃⋅R₅⋅R₇⋅Vᵢ + R₁⋅R₃⋅R₅⋅R₈⋅Vᵢ + R₁⋅R₃⋅R₇⋅R₈⋅Vᵢ
# ──────────────────────────────────────────────────────────────────────────────
# ₄⋅R₈ - R₂⋅R₄⋅R₅⋅R₇ - R₂⋅R₄⋅R₅⋅R₈ - R₂⋅R₄⋅R₇⋅R₈ - R₃⋅R₄⋅R₅⋅R₇ - R₃⋅R₄⋅R₅⋅R₈ - R
#
#
# ──────────, V₂: ──────────────────────────────────────────────────────────────
# ₃⋅R₄⋅R₇⋅R₈      R₁⋅R₂⋅R₃⋅R₇ + R₁⋅R₂⋅R₃⋅R₈ + R₁⋅R₂⋅R₄⋅R₇ + R₁⋅R₂⋅R₄⋅R₈ + R₁⋅R₂⋅
#
#                                                              -R₂⋅R₃⋅R₄⋅R₇⋅Vᵢ -
# ──────────────────────────────────────────────────────────────────────────────
# R₅⋅R₇ + R₁⋅R₂⋅R₅⋅R₈ + R₁⋅R₂⋅R₇⋅R₈ + R₁⋅R₃⋅R₄⋅R₇ + R₁⋅R₃⋅R₄⋅R₈ + R₁⋅R₃⋅R₅⋅R₇ +
#
#  R₂⋅R₃⋅R₄⋅R₈⋅Vᵢ
# ──────────────────────────────────────────────────────────────────────────────
# R₁⋅R₃⋅R₅⋅R₈ + R₁⋅R₃⋅R₇⋅R₈ - R₂⋅R₃⋅R₄⋅R₇ - R₂⋅R₃⋅R₄⋅R₈ - R₂⋅R₄⋅R₅⋅R₇ - R₂⋅R₄⋅R₅
#
#
# ───────────────────────────────────────────────────────────, V₃: ─────────────
# ⋅R₈ - R₂⋅R₄⋅R₇⋅R₈ - R₃⋅R₄⋅R₅⋅R₇ - R₃⋅R₄⋅R₅⋅R₈ - R₃⋅R₄⋅R₇⋅R₈      R₁⋅R₂⋅R₃⋅R₇ +
#
#
# ──────────────────────────────────────────────────────────────────────────────
#  R₁⋅R₂⋅R₃⋅R₈ + R₁⋅R₂⋅R₄⋅R₇ + R₁⋅R₂⋅R₄⋅R₈ + R₁⋅R₂⋅R₅⋅R₇ + R₁⋅R₂⋅R₅⋅R₈ + R₁⋅R₂⋅R
#
#                                 -R₂⋅R₃⋅R₄⋅R₇⋅Vᵢ - R₂⋅R₃⋅R₄⋅R₈⋅Vᵢ
# ──────────────────────────────────────────────────────────────────────────────
# ₇⋅R₈ + R₁⋅R₃⋅R₄⋅R₇ + R₁⋅R₃⋅R₄⋅R₈ + R₁⋅R₃⋅R₅⋅R₇ + R₁⋅R₃⋅R₅⋅R₈ + R₁⋅R₃⋅R₇⋅R₈ - R
#
#
# ──────────────────────────────────────────────────────────────────────────────
# ₂⋅R₃⋅R₄⋅R₇ - R₂⋅R₃⋅R₄⋅R₈ - R₂⋅R₄⋅R₅⋅R₇ - R₂⋅R₄⋅R₅⋅R₈ - R₂⋅R₄⋅R₇⋅R₈ - R₃⋅R₄⋅R₅⋅
#
#
# ──────────────────────────────, V₄: ──────────────────────────────────────────
# R₇ - R₃⋅R₄⋅R₅⋅R₈ - R₃⋅R₄⋅R₇⋅R₈      R₁⋅R₂⋅R₃⋅R₇ + R₁⋅R₂⋅R₃⋅R₈ + R₁⋅R₂⋅R₄⋅R₇ +
#
#                               -R₂⋅R₃⋅R₄⋅R₇⋅Vᵢ - R₂⋅R₃⋅R₄⋅R₈⋅Vᵢ - R₂⋅R₄⋅R₅⋅R₇⋅V
# ──────────────────────────────────────────────────────────────────────────────
# R₁⋅R₂⋅R₄⋅R₈ + R₁⋅R₂⋅R₅⋅R₇ + R₁⋅R₂⋅R₅⋅R₈ + R₁⋅R₂⋅R₇⋅R₈ + R₁⋅R₃⋅R₄⋅R₇ + R₁⋅R₃⋅R₄
#
# ᵢ - R₂⋅R₄⋅R₅⋅R₈⋅Vᵢ - R₂⋅R₄⋅R₇⋅R₈⋅Vᵢ - R₃⋅R₄⋅R₅⋅R₇⋅Vᵢ - R₃⋅R₄⋅R₅⋅R₈⋅Vᵢ - R₃⋅R₄⋅
# ──────────────────────────────────────────────────────────────────────────────
# ⋅R₈ + R₁⋅R₃⋅R₅⋅R₇ + R₁⋅R₃⋅R₅⋅R₈ + R₁⋅R₃⋅R₇⋅R₈ - R₂⋅R₃⋅R₄⋅R₇ - R₂⋅R₃⋅R₄⋅R₈ - R₂
#
# R₇⋅R₈⋅Vᵢ
# ──────────────────────────────────────────────────────────────────────────────
# ⋅R₄⋅R₅⋅R₇ - R₂⋅R₄⋅R₅⋅R₈ - R₂⋅R₄⋅R₇⋅R₈ - R₃⋅R₄⋅R₅⋅R₇ - R₃⋅R₄⋅R₅⋅R₈ - R₃⋅R₄⋅R₇⋅R
#
#
# ─, V₅: ───────────────────────────────────────────────────────────────────────
# ₈      R₁⋅R₂⋅R₃⋅R₇ + R₁⋅R₂⋅R₃⋅R₈ + R₁⋅R₂⋅R₄⋅R₇ + R₁⋅R₂⋅R₄⋅R₈ + R₁⋅R₂⋅R₅⋅R₇ + R
#
#                                    -R₂⋅R₄⋅R₅⋅R₇⋅Vᵢ - R₂⋅R₄⋅R₅⋅R₈⋅Vᵢ - R₃⋅R₄⋅R₅
# ──────────────────────────────────────────────────────────────────────────────
# ₁⋅R₂⋅R₅⋅R₈ + R₁⋅R₂⋅R₇⋅R₈ + R₁⋅R₃⋅R₄⋅R₇ + R₁⋅R₃⋅R₄⋅R₈ + R₁⋅R₃⋅R₅⋅R₇ + R₁⋅R₃⋅R₅⋅
#
# ⋅R₇⋅Vᵢ - R₃⋅R₄⋅R₅⋅R₈⋅Vᵢ
# ──────────────────────────────────────────────────────────────────────────────
# R₈ + R₁⋅R₃⋅R₇⋅R₈ - R₂⋅R₃⋅R₄⋅R₇ - R₂⋅R₃⋅R₄⋅R₈ - R₂⋅R₄⋅R₅⋅R₇ - R₂⋅R₄⋅R₅⋅R₈ - R₂⋅
#
#
# ──────────────────────────────────────────────────, V₇: ──────────────────────
# R₄⋅R₇⋅R₈ - R₃⋅R₄⋅R₅⋅R₇ - R₃⋅R₄⋅R₅⋅R₈ - R₃⋅R₄⋅R₇⋅R₈      R₁⋅R₂⋅R₃⋅R₇ + R₁⋅R₂⋅R₃
#
#
# ──────────────────────────────────────────────────────────────────────────────
# ⋅R₈ + R₁⋅R₂⋅R₄⋅R₇ + R₁⋅R₂⋅R₄⋅R₈ + R₁⋅R₂⋅R₅⋅R₇ + R₁⋅R₂⋅R₅⋅R₈ + R₁⋅R₂⋅R₇⋅R₈ + R₁
#
#                        -R₂⋅R₄⋅R₇⋅R₈⋅Vᵢ - R₃⋅R₄⋅R₇⋅R₈⋅Vᵢ
# ──────────────────────────────────────────────────────────────────────────────
# ⋅R₃⋅R₄⋅R₇ + R₁⋅R₃⋅R₄⋅R₈ + R₁⋅R₃⋅R₅⋅R₇ + R₁⋅R₃⋅R₅⋅R₈ + R₁⋅R₃⋅R₇⋅R₈ - R₂⋅R₃⋅R₄⋅R
#
#
# ──────────────────────────────────────────────────────────────────────────────
# ₇ - R₂⋅R₃⋅R₄⋅R₈ - R₂⋅R₄⋅R₅⋅R₇ - R₂⋅R₄⋅R₅⋅R₈ - R₂⋅R₄⋅R₇⋅R₈ - R₃⋅R₄⋅R₅⋅R₇ - R₃⋅R
#
#
# ─────────────────────, V₈: ───────────────────────────────────────────────────
# ₄⋅R₅⋅R₈ - R₃⋅R₄⋅R₇⋅R₈      R₁⋅R₂⋅R₃⋅R₇ + R₁⋅R₂⋅R₃⋅R₈ + R₁⋅R₂⋅R₄⋅R₇ + R₁⋅R₂⋅R₄⋅
#
#                                                                         -R₂⋅R₄
# ──────────────────────────────────────────────────────────────────────────────
# R₈ + R₁⋅R₂⋅R₅⋅R₇ + R₁⋅R₂⋅R₅⋅R₈ + R₁⋅R₂⋅R₇⋅R₈ + R₁⋅R₃⋅R₄⋅R₇ + R₁⋅R₃⋅R₄⋅R₈ + R₁⋅
#
# ⋅R₇⋅R₈⋅Vᵢ - R₃⋅R₄⋅R₇⋅R₈⋅Vᵢ
# ──────────────────────────────────────────────────────────────────────────────
# R₃⋅R₅⋅R₇ + R₁⋅R₃⋅R₅⋅R₈ + R₁⋅R₃⋅R₇⋅R₈ - R₂⋅R₃⋅R₄⋅R₇ - R₂⋅R₃⋅R₄⋅R₈ - R₂⋅R₄⋅R₅⋅R₇
#
#                                                                       ⎫
# ──────────────────────────────────────────────────────────────────────⎬
#  - R₂⋅R₄⋅R₅⋅R₈ - R₂⋅R₄⋅R₇⋅R₈ - R₃⋅R₄⋅R₅⋅R₇ - R₃⋅R₄⋅R₅⋅R₈ - R₃⋅R₄⋅R₇⋅R₈⎭

# %%
s[V8]
# Out:
#
# ──────────────────────────────────────────────────────────────────────────────
# R₁⋅R₂⋅R₃⋅R₇ + R₁⋅R₂⋅R₃⋅R₈ + R₁⋅R₂⋅R₄⋅R₇ + R₁⋅R₂⋅R₄⋅R₈ + R₁⋅R₂⋅R₅⋅R₇ + R₁⋅R₂⋅R₅
#
#                                              -R₂⋅R₄⋅R₇⋅R₈⋅Vᵢ - R₃⋅R₄⋅R₇⋅R₈⋅Vᵢ
# ──────────────────────────────────────────────────────────────────────────────
# ⋅R₈ + R₁⋅R₂⋅R₇⋅R₈ + R₁⋅R₃⋅R₄⋅R₇ + R₁⋅R₃⋅R₄⋅R₈ + R₁⋅R₃⋅R₅⋅R₇ + R₁⋅R₃⋅R₅⋅R₈ + R₁
#
#
# ──────────────────────────────────────────────────────────────────────────────
# ⋅R₃⋅R₇⋅R₈ - R₂⋅R₃⋅R₄⋅R₇ - R₂⋅R₃⋅R₄⋅R₈ - R₂⋅R₄⋅R₅⋅R₇ - R₂⋅R₄⋅R₅⋅R₈ - R₂⋅R₄⋅R₇⋅R
#
#
# ───────────────────────────────────────────
# ₈ - R₃⋅R₄⋅R₅⋅R₇ - R₃⋅R₄⋅R₅⋅R₈ - R₃⋅R₄⋅R₇⋅R₈

# %%
s[V8].subs({R1:1000,
            R2:1000,
            R3:1000,
            R5:5000,
            R7:1000,
            R4:1000,
            R8:1000,
            Vi:20}).simplify()
# Out:
# -10

# %% [markdown]
# Considerando que todas las resistencias son de $1 k\Omega$, encuentre los voltajes para cuando $Vi = 15V$

# %%
# Celda para código

# %% [markdown]
# Considerando que todas las resistencias son de $5 k\Omega$, encuentre los voltajes para cuando $Vi = 10V$

# %%
# Celda para código

# %% [markdown]
# Considerando que $ R1 = R2 = R4 = 5 k\Omega$, $ R3 = R5 = R8 = 2 k\Omega$ y $ R6 = R7 = 100 \Omega$, encuentre los voltajes para cuando $Vi = 12V$

# %%
# Celda para código
