# %% [markdown]
# # Modelo dinámico de un circuito RLC

# %%
import sympy as sym
sym.init_printing()
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# | Elemento | Dominio del tiempo  (EDO)|
# |:---:|:---:|
# | ![Resistancia](figuras/resistor.png) | $u(t) = R \cdot i(t)$ | $U(s) = R \cdot I(s)$ | $R$ |
# | ![Inductor](figuras/inductor.png) | $\begin{matrix} u(t) = L \frac{d}{dt} i(t) \\ i(t) = \frac{1}{L} \int_{0}^{t} u(\tau) d\tau + i(0+) \epsilon(t) \end{matrix}$ | $\begin{matrix} U(s) = s L I(s) - L i(0+) \\ I(s) = \frac{1}{s L} U(s) + \frac{1}{s} i(0+) \end{matrix}$ | $s L$ |
# | ![Capacitor](figuras/capacitor.png) | $\begin{matrix} u(t) = \frac{1}{C} \int_{0}^{t} i(\tau) d\tau + u(0+) \epsilon(t) \\ i(t) = C \frac{d}{dt} u(t) \end{matrix}$ | $\begin{matrix} U(s) = \frac{1}{s C} I(s) + \frac{1}{s} u(0+) \\ I(s) = s C U(s) - C u(0+) \end{matrix}$ | $\frac{1}{s C}$

# %% [markdown]
# Considere el circuito que se muestra en la figura. Suponga que la entrada es el voltaje $x(t)$ y la salida es el voltaje $y(t)$. Suponga además que no hay energía almacenada en los elementos que almacenan energía en $t<0$. Además, considere que $x(t)=0 \forall t<0$.
#
# ![bloque](figuras/bloque_tiempo.PNG)
#
#
# ![Circuito](figuras/lowpass.png)

# %% [markdown]
# El voltaje $x(t)$ es igual a los voltajes que caen en la red $RLC$.
#
#
# \begin{align}
# v_R(t) + v_L(t) + v_C(t) &= x(t) \\
# R i(t) + L \frac{di}{dt} + \frac{1}{C} \int_{0}^{t} i(\tau) d\tau &= x(t) \\
# \end{align}
#
# La salida $y(t)$ es el voltaje del capacitor.
#
# \begin{equation}
# y(t) = \frac{1}{C} \int_{0}^{t} i(\tau) d\tau
# \end{equation}
#
# De donde se obtiene la corriente $i(t)$
#
# \begin{equation}
# C \frac{dy}{dt} = i(t)
# \end{equation}
#
# Incorporando las expresiones de la salida $y(t)$ y la variable interna $i(t)$ en la ecuación de la malla se obtiene
#
# \begin{align}
# R i(t) + L \frac{di}{dt} + \frac{1}{C} \int_{0}^{t} i(\tau) d\tau &= x(t) \\
# C R \frac{d y(t)}{dt} + C L \frac{d^2 y(t)}{dt^2} + y(t)& = x(t) \\
# \end{align}
#
# -------------------

# %% [markdown]
# \begin{equation}
# y(t) = \frac{1}{C} \int_{0}^{t} i(\tau) d\tau
# \end{equation}

# %% [markdown]
# \begin{equation}
# C \cdot y(t) = C \cdot \frac{1}{C} \int_{0}^{t} i(\tau) d\tau
# \end{equation}

# %% [markdown]
# \begin{equation}
# C \cdot y(t) =  \int_{0}^{t} i(\tau) d\tau
# \end{equation}

# %% [markdown]
# \begin{equation}
# \frac{d}{dt} (C \cdot y(t)) =  \frac{d}{dt}(\int_{0}^{t} i(\tau) d\tau)
# \end{equation}

# %% [markdown]
# \begin{equation}
# C \frac{dy}{dt} =  i(t)
# \end{equation}

# %%
t, L, R, C = sym.symbols('t L R C', real=True)
x = sym.Function('x')(t)
y = sym.Function('y')(t)

ode = sym.Eq(C*R*y.diff(t) + C*L*y.diff(t, 2) +  y, x)
ode
# Out:
#       2
#      d              d
# C⋅L⋅───(y(t)) + C⋅R⋅──(y(t)) + y(t) = x(t)
#       2             dt
#     dt

# %% [markdown]
# $$CL(j\omega)^{2}Y(j\omega)+CRj\omega Y(j\omega)+Y(j\omega) = X(j\omega)$$
# $$-CL\omega^{2}Y(j\omega)+CRj\omega Y(j\omega)+Y(j\omega) = X(j\omega)$$

# %% [markdown]
# Dada una entrada $x(t)$, se puede calcular la solución del sistema. Observe que al usar `dsolve` obtiene la solución general de la homogénea relacionada junto a la solución particular.

# %%
u = sym.Heaviside(t)
# u = sym.Heaviside(t)*t
# sol = sym.dsolve( ode.subs(x,u))
sol = sym.dsolve( ode.subs(x,u))
sol
# Out:
#
#
#
#
#
#
#
#
#
#
#                                                                              ⎛
#                                                                              ⎜
#                                                                              ⎜
#                                                                              ⎜
#                                                                              ⎜
#                                                                              ⎜
#                                                                              ⎜
#                                                                              ⎜
#              ⎛        ________________⎞         ⎛        ________________⎞   ⎜
#              ⎜       ╱   ⎛   2      ⎞ ⎟         ⎜       ╱   ⎛   2      ⎞ ⎟   ⎜
#              ⎜     ╲╱  C⋅⎝C⋅R  - 4⋅L⎠ ⎟         ⎜     ╲╱  C⋅⎝C⋅R  - 4⋅L⎠ ⎟   ⎜
#            t⋅⎜-R - ───────────────────⎟       t⋅⎜-R + ───────────────────⎟   ⎜
#              ⎝              C         ⎠         ⎝              C         ⎠   ⎜
#            ────────────────────────────       ────────────────────────────   ⎜
#                        2⋅L                                2⋅L                ⎝
# y(t) = C₁⋅ℯ                             + C₂⋅ℯ                             - ─
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ⎧⎧                                       _______________
# ⎪⎪         2⋅C⋅L                        ╱  2  2
# ⎪⎪────────────────────────  for C⋅R - ╲╱  C ⋅R  - 4⋅C⋅L  ≠ 0               ___
# ⎪⎪         _______________                                                ╱  2
# ⎪⎨        ╱  2  2                                             for C⋅R - ╲╱  C
# ⎪⎪C⋅R - ╲╱  C ⋅R  - 4⋅C⋅L
# ⎪⎪
# ⎨⎪           0                         otherwise
# ⎪⎩
# ⎪
# ⎪                          2⋅C⋅L
# ⎪                 ────────────────────────                               other
# ⎪                          _______________
# ⎪                         ╱  2  2
# ⎩                 C⋅R - ╲╱  C ⋅R  - 4⋅C⋅L
# ──────────────────────────────────────────────────────────────────────────────
#                                                               ________________
#                                                              ╱   ⎛   2      ⎞
#                                                            ╲╱  C⋅⎝C⋅R  - 4⋅L⎠
#
#
#
#
#
#
#
#
#
#
#
#                 ⎞    ⎛        ________________⎞                ⎛⎧⎧
#                 ⎟    ⎜       ╱   ⎛   2      ⎞ ⎟                ⎜⎪⎪         2⋅C
# ____________    ⎟    ⎜     ╲╱  C⋅⎝C⋅R  - 4⋅L⎠ ⎟                ⎜⎪⎪────────────
#   2             ⎟  t⋅⎜-R + ───────────────────⎟                ⎜⎪⎪         ___
# ⋅R  - 4⋅C⋅L  = 0⎟    ⎝              C         ⎠                ⎜⎪⎨        ╱  2
#                 ⎟  ────────────────────────────                ⎜⎪⎪C⋅R + ╲╱  C
#                 ⎟              2⋅L                             ⎜⎪⎪
#                 ⎟⋅ℯ                            ⋅Heaviside(t)   ⎜⎨⎪           0
#                 ⎟                                              ⎜⎪⎩
#                 ⎟                                              ⎜⎪
#                 ⎟                                              ⎜⎪
# wise            ⎟                                              ⎜⎪
#                 ⎟                                              ⎜⎪
#                 ⎟                                              ⎜⎪
#                 ⎠                                              ⎝⎩
# ──────────────────────────────────────────────────────────── + ───────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                            _______________
# ⋅L                        ╱  2  2
# ────────────  for C⋅R + ╲╱  C ⋅R  - 4⋅C⋅L  ≠ 0               _______________
# ____________                                                ╱  2  2
#   2                                             for C⋅R + ╲╱  C ⋅R  - 4⋅C⋅L  =
# ⋅R  - 4⋅C⋅L
#
#                          otherwise
#
#
#              2⋅C⋅L
#     ────────────────────────                               otherwise
#              _______________
#             ╱  2  2
#     C⋅R + ╲╱  C ⋅R  - 4⋅C⋅L
# ──────────────────────────────────────────────────────────────────────────────
#                                                 ________________
#                                                ╱   ⎛   2      ⎞
#                                              ╲╱  C⋅⎝C⋅R  - 4⋅L⎠
#
#                                                  ⎛⎧⎧                  ________
#                                                  ⎜⎪⎪                 ╱  2  2
#                                                  ⎜⎪⎪       R⋅t   t⋅╲╱  C ⋅R  -
#                                                  ⎜⎪⎪       ─── - ─────────────
#                                                  ⎜⎪⎪       2⋅L          2⋅C⋅L
#                                                  ⎜⎪⎪2⋅C⋅L⋅ℯ
#                                                  ⎜⎪⎨──────────────────────────
#                                                  ⎜⎪⎪              ____________
#                                                  ⎜⎪⎪             ╱  2  2
#                                                  ⎜⎪⎪     C⋅R - ╲╱  C ⋅R  - 4⋅C
#   ⎞    ⎛        ________________⎞                ⎜⎪⎪
#   ⎟    ⎜       ╱   ⎛   2      ⎞ ⎟                ⎜⎪⎪                t
#   ⎟    ⎜     ╲╱  C⋅⎝C⋅R  - 4⋅L⎠ ⎟                ⎜⎨⎩
#   ⎟  t⋅⎜-R - ───────────────────⎟                ⎜⎪
#  0⎟    ⎝              C         ⎠                ⎜⎪
#   ⎟  ────────────────────────────                ⎜⎪
#   ⎟              2⋅L                             ⎜⎪                        R⋅t
#   ⎟⋅ℯ                            ⋅Heaviside(t)   ⎜⎪                        ───
#   ⎟                                              ⎜⎪                        2⋅L
#   ⎟                                              ⎜⎪                 2⋅C⋅L⋅ℯ
#   ⎟                                              ⎜⎪                 ──────────
#   ⎟                                              ⎜⎪
#   ⎟                                              ⎜⎪
#   ⎟                                              ⎜⎪                      C⋅R -
#   ⎠                                              ⎝⎩
# ────────────────────────────────────────────── + ─────────────────────────────
#
#
#
#
# _______                                                                    ⎞
#                                                                            ⎟
#  4⋅C⋅L                                                                     ⎟
# ───────                                                                    ⎟
#                       _______________                   _______________    ⎟
#                      ╱  2  2                           ╱  2  2             ⎟
# ───────  for C⋅R - ╲╱  C ⋅R  - 4⋅C⋅L  ≠ 0  for C⋅R - ╲╱  C ⋅R  - 4⋅C⋅L  = 0⎟
# ___                                                                        ⎟
#                                                                            ⎟
# ⋅L                                                                         ⎟
#                                                                            ⎟
#                     otherwise                                              ⎟
#                                                                            ⎟⋅ℯ
#                                                                            ⎟
#         _______________                                                    ⎟
#        ╱  2  2                                                             ⎟
#    t⋅╲╱  C ⋅R  - 4⋅C⋅L                                                     ⎟
#  - ────────────────────                                                    ⎟
#           2⋅C⋅L                                                            ⎟
#                                                                            ⎟
# ───────────────────────                               otherwise            ⎟
#     _______________                                                        ⎟
#    ╱  2  2                                                                 ⎟
#  ╲╱  C ⋅R  - 4⋅C⋅L                                                         ⎟
#                                                                            ⎠
# ──────────────────────────────────────────────────────────────────────────────
#                                       ________________
#                                      ╱   ⎛   2      ⎞
#                                    ╲╱  C⋅⎝C⋅R  - 4⋅L⎠
#
#                                             ⎛⎧⎧                  _____________
#                                             ⎜⎪⎪                 ╱  2  2
#                                             ⎜⎪⎪       R⋅t   t⋅╲╱  C ⋅R  - 4⋅C⋅
#                                             ⎜⎪⎪       ─── + ──────────────────
#                                             ⎜⎪⎪       2⋅L          2⋅C⋅L
#   ⎛        ________________⎞                ⎜⎪⎪2⋅C⋅L⋅ℯ
#   ⎜       ╱   ⎛   2      ⎞ ⎟                ⎜⎪⎨───────────────────────────────
#   ⎜     ╲╱  C⋅⎝C⋅R  - 4⋅L⎠ ⎟                ⎜⎪⎪              _______________
# t⋅⎜-R + ───────────────────⎟                ⎜⎪⎪             ╱  2  2
#   ⎝              C         ⎠                ⎜⎪⎪     C⋅R + ╲╱  C ⋅R  - 4⋅C⋅L
# ────────────────────────────                ⎜⎪⎪
#             2⋅L                             ⎜⎪⎪                t
#                             ⋅Heaviside(t)   ⎜⎨⎩
#                                             ⎜⎪
#                                             ⎜⎪
#                                             ⎜⎪
#                                             ⎜⎪                        R⋅t   t⋅
#                                             ⎜⎪                        ─── + ──
#                                             ⎜⎪                        2⋅L
#                                             ⎜⎪                 2⋅C⋅L⋅ℯ
#                                             ⎜⎪                 ───────────────
#                                             ⎜⎪                               _
#                                             ⎜⎪                              ╱
#                                             ⎜⎪                      C⋅R + ╲╱
#                                             ⎝⎩
# ───────────────────────────────────────── - ──────────────────────────────────
#
#
#
#
# __                                                                    ⎞
#                                                                       ⎟
# L                                                                     ⎟
# ──                                                                    ⎟
#                  _______________                   _______________    ⎟
#                 ╱  2  2                           ╱  2  2             ⎟    ⎛
# ──  for C⋅R + ╲╱  C ⋅R  - 4⋅C⋅L  ≠ 0  for C⋅R + ╲╱  C ⋅R  - 4⋅C⋅L  = 0⎟    ⎜
#                                                                       ⎟    ⎜
#                                                                       ⎟  t⋅⎜-R
#                                                                       ⎟    ⎝
#                                                                       ⎟  ─────
#                otherwise                                              ⎟
#                                                                       ⎟⋅ℯ
#                                                                       ⎟
#    _______________                                                    ⎟
#   ╱  2  2                                                             ⎟
# ╲╱  C ⋅R  - 4⋅C⋅L                                                     ⎟
# ──────────────────                                                    ⎟
#      2⋅C⋅L                                                            ⎟
#                                                                       ⎟
# ──────────────────                               otherwise            ⎟
# ______________                                                        ⎟
#  2  2                                                                 ⎟
# C ⋅R  - 4⋅C⋅L                                                         ⎟
#                                                                       ⎠
# ──────────────────────────────────────────────────────────────────────────────
#                                  ________________
#                                 ╱   ⎛   2      ⎞
#                               ╲╱  C⋅⎝C⋅R  - 4⋅L⎠
#
#
#
#
#
#
#       ________________⎞
#      ╱   ⎛   2      ⎞ ⎟
#    ╲╱  C⋅⎝C⋅R  - 4⋅L⎠ ⎟
#  - ───────────────────⎟
#             C         ⎠
# ───────────────────────
#        2⋅L
#                        ⋅Heaviside(t)
#
#
#
#
#
#
#
#
#
#
#
#
# ────────────────────────────────────

# %% [markdown]
# Las constantes $C_1$ y $C_2$ deben calcularse para satisfacer las condiciones iniciales  $y(t) = 0$ and $\frac{d y(t)}{dt} = 0$ para $t<0$.

# %%
C_int = sym.solve((sol.rhs.limit(t, 0, '-'),
                   sol.rhs.diff(t).limit(t, 0, '-')),
                  ['C1', 'C2'])
C_int
# Out:
# {C₁: 0, C₂: 0}

# %%
sol = sol.subs(C_int)
sol
# Out:
#
#
#
#
#
#
#
#
#
#
#          ⎛⎧⎧                                       _______________
#          ⎜⎪⎪         2⋅C⋅L                        ╱  2  2
#          ⎜⎪⎪────────────────────────  for C⋅R - ╲╱  C ⋅R  - 4⋅C⋅L  ≠ 0
#          ⎜⎪⎪         _______________
#          ⎜⎪⎨        ╱  2  2                                             for C⋅
#          ⎜⎪⎪C⋅R - ╲╱  C ⋅R  - 4⋅C⋅L
#          ⎜⎪⎪
#          ⎜⎨⎪           0                         otherwise
#          ⎜⎪⎩
#          ⎜⎪
#          ⎜⎪                          2⋅C⋅L
#          ⎜⎪                 ────────────────────────
#          ⎜⎪                          _______________
#          ⎜⎪                         ╱  2  2
#          ⎝⎩                 C⋅R - ╲╱  C ⋅R  - 4⋅C⋅L
# y(t) = - ─────────────────────────────────────────────────────────────────────
#                                                                         ______
#                                                                        ╱   ⎛
#                                                                      ╲╱  C⋅⎝C⋅
#
#
#
#
#
#
#
#
#
#
#
#                           ⎞    ⎛        ________________⎞                ⎛⎧⎧
#                           ⎟    ⎜       ╱   ⎛   2      ⎞ ⎟                ⎜⎪⎪
#        _______________    ⎟    ⎜     ╲╱  C⋅⎝C⋅R  - 4⋅L⎠ ⎟                ⎜⎪⎪──
#       ╱  2  2             ⎟  t⋅⎜-R + ───────────────────⎟                ⎜⎪⎪
# R - ╲╱  C ⋅R  - 4⋅C⋅L  = 0⎟    ⎝              C         ⎠                ⎜⎪⎨
#                           ⎟  ────────────────────────────                ⎜⎪⎪C⋅
#                           ⎟              2⋅L                             ⎜⎪⎪
#                           ⎟⋅ℯ                            ⋅Heaviside(t)   ⎜⎨⎪
#                           ⎟                                              ⎜⎪⎩
#                           ⎟                                              ⎜⎪
#                           ⎟                                              ⎜⎪
#      otherwise            ⎟                                              ⎜⎪
#                           ⎟                                              ⎜⎪
#                           ⎟                                              ⎜⎪
#                           ⎠                                              ⎝⎩
# ────────────────────────────────────────────────────────────────────── + ─────
# __________
#  2      ⎞
# R  - 4⋅L⎠
#
#
#
#
#
#
#
#
#
#
#
#                                      _______________
#        2⋅C⋅L                        ╱  2  2
# ──────────────────────  for C⋅R + ╲╱  C ⋅R  - 4⋅C⋅L  ≠ 0               _______
#        _______________                                                ╱  2  2
#       ╱  2  2                                             for C⋅R + ╲╱  C ⋅R
# R + ╲╱  C ⋅R  - 4⋅C⋅L
#
#          0                         otherwise
#
#
#                        2⋅C⋅L
#               ────────────────────────                               otherwise
#                        _______________
#                       ╱  2  2
#               C⋅R + ╲╱  C ⋅R  - 4⋅C⋅L
# ──────────────────────────────────────────────────────────────────────────────
#                                                           ________________
#                                                          ╱   ⎛   2      ⎞
#                                                        ╲╱  C⋅⎝C⋅R  - 4⋅L⎠
#
#                                                            ⎛⎧⎧
#                                                            ⎜⎪⎪
#                                                            ⎜⎪⎪       R⋅t   t⋅╲
#                                                            ⎜⎪⎪       ─── - ───
#                                                            ⎜⎪⎪       2⋅L
#                                                            ⎜⎪⎪2⋅C⋅L⋅ℯ
#                                                            ⎜⎪⎨────────────────
#                                                            ⎜⎪⎪              __
#                                                            ⎜⎪⎪             ╱
#                                                            ⎜⎪⎪     C⋅R - ╲╱  C
#             ⎞    ⎛        ________________⎞                ⎜⎪⎪
#             ⎟    ⎜       ╱   ⎛   2      ⎞ ⎟                ⎜⎪⎪
# ________    ⎟    ⎜     ╲╱  C⋅⎝C⋅R  - 4⋅L⎠ ⎟                ⎜⎨⎩
#             ⎟  t⋅⎜-R - ───────────────────⎟                ⎜⎪
# - 4⋅C⋅L  = 0⎟    ⎝              C         ⎠                ⎜⎪
#             ⎟  ────────────────────────────                ⎜⎪
#             ⎟              2⋅L                             ⎜⎪
#             ⎟⋅ℯ                            ⋅Heaviside(t)   ⎜⎪
#             ⎟                                              ⎜⎪
#             ⎟                                              ⎜⎪
#             ⎟                                              ⎜⎪
#             ⎟                                              ⎜⎪
#             ⎟                                              ⎜⎪
#             ⎟                                              ⎜⎪
#             ⎠                                              ⎝⎩
# ──────────────────────────────────────────────────────── + ───────────────────
#
#
#
#
#   _______________
#  ╱  2  2
# ╱  C ⋅R  - 4⋅C⋅L
# ─────────────────
#     2⋅C⋅L                       _______________                   ____________
#                                ╱  2  2                           ╱  2  2
# ─────────────────  for C⋅R - ╲╱  C ⋅R  - 4⋅C⋅L  ≠ 0  for C⋅R - ╲╱  C ⋅R  - 4⋅C
# _____________
# 2  2
#  ⋅R  - 4⋅C⋅L
#
# t                             otherwise
#
#
#                   _______________
#                  ╱  2  2
#        R⋅t   t⋅╲╱  C ⋅R  - 4⋅C⋅L
#        ─── - ────────────────────
#        2⋅L          2⋅C⋅L
# 2⋅C⋅L⋅ℯ
# ─────────────────────────────────                               otherwise
#               _______________
#              ╱  2  2
#      C⋅R - ╲╱  C ⋅R  - 4⋅C⋅L
#
# ──────────────────────────────────────────────────────────────────────────────
#                                                 ________________
#                                                ╱   ⎛   2      ⎞
#                                              ╲╱  C⋅⎝C⋅R  - 4⋅L⎠
#
#        ⎞                                              ⎛⎧⎧                  ___
#        ⎟                                              ⎜⎪⎪                 ╱  2
#        ⎟                                              ⎜⎪⎪       R⋅t   t⋅╲╱  C
#        ⎟                                              ⎜⎪⎪       ─── + ────────
# ___    ⎟                                              ⎜⎪⎪       2⋅L          2
#        ⎟    ⎛        ________________⎞                ⎜⎪⎪2⋅C⋅L⋅ℯ
# ⋅L  = 0⎟    ⎜       ╱   ⎛   2      ⎞ ⎟                ⎜⎪⎨─────────────────────
#        ⎟    ⎜     ╲╱  C⋅⎝C⋅R  - 4⋅L⎠ ⎟                ⎜⎪⎪              _______
#        ⎟  t⋅⎜-R + ───────────────────⎟                ⎜⎪⎪             ╱  2  2
#        ⎟    ⎝              C         ⎠                ⎜⎪⎪     C⋅R + ╲╱  C ⋅R
#        ⎟  ────────────────────────────                ⎜⎪⎪
#        ⎟              2⋅L                             ⎜⎪⎪                t
#        ⎟⋅ℯ                            ⋅Heaviside(t)   ⎜⎨⎩
#        ⎟                                              ⎜⎪
#        ⎟                                              ⎜⎪
#        ⎟                                              ⎜⎪
#        ⎟                                              ⎜⎪
#        ⎟                                              ⎜⎪
#        ⎟                                              ⎜⎪
#        ⎟                                              ⎜⎪                 2⋅C⋅L
#        ⎟                                              ⎜⎪                 ─────
#        ⎟                                              ⎜⎪
#        ⎟                                              ⎜⎪
#        ⎟                                              ⎜⎪
#        ⎠                                              ⎝⎩
# ─────────────────────────────────────────────────── - ────────────────────────
#
#
#
#
# ____________
#   2
# ⋅R  - 4⋅C⋅L
# ────────────
# ⋅C⋅L                       _______________                   _______________
#                           ╱  2  2                           ╱  2  2
# ────────────  for C⋅R + ╲╱  C ⋅R  - 4⋅C⋅L  ≠ 0  for C⋅R + ╲╱  C ⋅R  - 4⋅C⋅L  =
# ________
#
# - 4⋅C⋅L
#
#                          otherwise
#
#
#              _______________
#             ╱  2  2
#   R⋅t   t⋅╲╱  C ⋅R  - 4⋅C⋅L
#   ─── + ────────────────────
#   2⋅L          2⋅C⋅L
# ⋅ℯ
# ────────────────────────────                               otherwise
#          _______________
#         ╱  2  2
# C⋅R + ╲╱  C ⋅R  - 4⋅C⋅L
#
# ──────────────────────────────────────────────────────────────────────────────
#                                            ________________
#                                           ╱   ⎛   2      ⎞
#                                         ╲╱  C⋅⎝C⋅R  - 4⋅L⎠
#
#   ⎞
#   ⎟
#   ⎟
#   ⎟
#   ⎟
#   ⎟    ⎛        ________________⎞
#  0⎟    ⎜       ╱   ⎛   2      ⎞ ⎟
#   ⎟    ⎜     ╲╱  C⋅⎝C⋅R  - 4⋅L⎠ ⎟
#   ⎟  t⋅⎜-R - ───────────────────⎟
#   ⎟    ⎝              C         ⎠
#   ⎟  ────────────────────────────
#   ⎟              2⋅L
#   ⎟⋅ℯ                            ⋅Heaviside(t)
#   ⎟
#   ⎟
#   ⎟
#   ⎟
#   ⎟
#   ⎟
#   ⎟
#   ⎟
#   ⎟
#   ⎟
#   ⎟
#   ⎠
# ──────────────────────────────────────────────

# %%
RLC = {R: 2,     
       L: 0.05,
       C: .03}
RLC
# Out:
# {C: 0.03, L: 0.05, R: 2}

# %%
tlaps = (t,-10e-3,0.5*10e-1)

plt.rcParams['figure.figsize'] = 9, 3

sym.plot(sol.rhs.subs(RLC), tlaps, line_color='red',
         ylabel = '$y(t)$',);

sym.plot(u, tlaps, line_color='blue',
         ylabel = '$x(t)$',);

# %%
sol.rhs.subs(RLC)
# Out:
#                                                    10.0⋅t⋅(2 - 1.6329931618554
# 10.2062072615966⋅ⅈ⋅(-0.06 - 0.0489897948556636⋅ⅈ)⋅ℯ
#
# 5⋅ⅈ)  -20.0⋅t + 16.3299316185545⋅ⅈ⋅t
#     ⋅ℯ                              ⋅Heaviside(t) - 20.4124145231931⋅ⅈ⋅(-0.03
#
#                          10.0⋅t⋅(2 - 1.63299316185545⋅ⅈ)
# - 0.0244948974278318⋅ⅈ)⋅ℯ                               ⋅Heaviside(t) - 10.206
#
#                                              10.0⋅t⋅(2 + 1.63299316185545⋅ⅈ)
# 2072615966⋅ⅈ⋅(-0.06 + 0.0489897948556636⋅ⅈ)⋅ℯ                               ⋅ℯ
#
# -20.0⋅t - 16.3299316185545⋅ⅈ⋅t
#                               ⋅Heaviside(t) + 20.4124145231931⋅ⅈ⋅(-0.03 + 0.02
#
#                    10.0⋅t⋅(2 + 1.63299316185545⋅ⅈ)
# 44948974278318⋅ⅈ)⋅ℯ                               ⋅Heaviside(t)
